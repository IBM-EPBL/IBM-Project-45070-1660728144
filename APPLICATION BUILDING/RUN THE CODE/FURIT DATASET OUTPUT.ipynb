# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator (rescale = 1./255, shear_range= 0.2,zoom_range= 0.2, horizontal_flip = True)

# %%
test_datagen =ImageDataGenerator (rescale = 1)

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\train",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
# Out:
# Found 5384 images belonging to 6 classes.
# Found 1686 images belonging to 6 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from tensorflow.keras.models import load_model

# %%
model=Sequential()

# %%
model.add(Convolution2D(32,(3,3),input_shape=(128,128,3),activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(units=40,kernel_initializer='uniform',activation='relu'))

# %%
model.add(Dense(units=70,kernel_initializer='random_uniform',activation='relu'))

# %%
model.add(Dense(units=6,kernel_initializer='random_uniform',activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x_train,steps_per_epoch=168,epochs=3,validation_data=x_test,validation_steps=52)
# Out:
# Epoch 1/3
# 168/168 [==============================] - 102s 598ms/step - loss: 0.8219 - accuracy: 0.7029 - val_loss: 48.7613 - val_accuracy: 0.8510
# Epoch 2/3
# 168/168 [==============================] - 101s 600ms/step - loss: 0.3760 - accuracy: 0.8716 - val_loss: 69.5913 - val_accuracy: 0.8516
# Epoch 3/3
# 168/168 [==============================] - 98s 584ms/step - loss: 0.2877 - accuracy: 0.9021 - val_loss: 212.2739 - val_accuracy: 0.7572

# %%
model.save(r"C:\Users\DELL\Desktop\fruit-dataset.h5")

# %%
model.fit(x_train,steps_per_epoch=len(x_train),validation_data=x_test,validation_steps=len(x_test),epochs=10)
# Out:
# Epoch 1/10
# 169/169 [==============================] - 100s 591ms/step - loss: 0.2747 - accuracy: 0.9047 - val_loss: 149.4370 - val_accuracy: 0.7776
# Epoch 2/10
# 169/169 [==============================] - 99s 584ms/step - loss: 0.2373 - accuracy: 0.9144 - val_loss: 218.6362 - val_accuracy: 0.7568
# Epoch 3/10
# 169/169 [==============================] - 66s 386ms/step - loss: 0.2049 - accuracy: 0.9277 - val_loss: 310.9743 - val_accuracy: 0.7230
# Epoch 4/10
# 169/169 [==============================] - 51s 304ms/step - loss: 0.1796 - accuracy: 0.9337 - val_loss: 531.8726 - val_accuracy: 0.6352
# Epoch 5/10
# 169/169 [==============================] - 51s 299ms/step - loss: 0.1603 - accuracy: 0.9432 - val_loss: 527.5671 - val_accuracy: 0.6133
# Epoch 6/10
# 169/169 [==============================] - 46s 270ms/step - loss: 0.1337 - accuracy: 0.9528 - val_loss: 737.7686 - val_accuracy: 0.6038
# Epoch 7/10
# 169/169 [==============================] - 48s 283ms/step - loss: 0.1304 - accuracy: 0.9569 - val_loss: 935.3660 - val_accuracy: 0.5427
# Epoch 8/10
# 169/169 [==============================] - 46s 273ms/step - loss: 0.1310 - accuracy: 0.9543 - val_loss: 696.4323 - val_accuracy: 0.6186
# Epoch 9/10
# 169/169 [==============================] - 48s 284ms/step - loss: 0.1168 - accuracy: 0.9599 - val_loss: 702.1434 - val_accuracy: 0.6103
# Epoch 10/10
# 169/169 [==============================] - 48s 281ms/step - loss: 0.1182 - accuracy: 0.9582 - val_loss: 1122.5823 - val_accuracy: 0.5219

# %%
model.save('fruit-dataset.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  flatten (Flatten)           (None, 127008)            0
#
#  dense (Dense)               (None, 40)                5080360
#
#  dense_1 (Dense)             (None, 70)                2870
#
#  dense_2 (Dense)             (None, 6)                 426
#
# =================================================================
# Total params: 5,084,552
# Trainable params: 5,084,552
# Non-trainable params: 0
# _________________________________________________________________

# %%
model=load_model('fruit-dataset.h5')

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\DELL\Desktop\test\Peach___Bacterial_spot\0c1c3a6a-3454-4154-8ca9-08ff1e39d6c8___Rutg._Bact.S 1642.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img=image.load_img(r"C:\Users\DELL\Desktop\test\Peach___Bacterial_spot\0c1c3a6a-3454-4154-8ca9-08ff1e39d6c8___Rutg._Bact.S 1642.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
x=image.img_to_array(img)
x
# Out:
# array([[[148., 149., 153.],
#         [148., 149., 153.],
#         [148., 149., 153.],
#         ...,
#         [153., 150., 157.],
#         [153., 150., 157.],
#         [153., 150., 157.]],
#
#        [[146., 147., 151.],
#         [146., 147., 151.],
#         [146., 147., 151.],
#         ...,
#         [152., 149., 156.],
#         [152., 149., 156.],
#         [153., 150., 157.]],
#
#        [[145., 146., 150.],
#         [145., 146., 150.],
#         [145., 146., 150.],
#         ...,
#         [150., 147., 154.],
#         [152., 149., 156.],
#         [154., 151., 158.]],
#
#        ...,
#
#        [[122., 118., 119.],
#         [131., 127., 128.],
#         [103.,  99., 100.],
#         ...,
#         [141., 136., 140.],
#         [120., 115., 119.],
#         [139., 134., 138.]],
#
#        [[134., 130., 131.],
#         [ 82.,  78.,  79.],
#         [108., 104., 105.],
#         ...,
#         [129., 124., 128.],
#         [130., 125., 129.],
#         [133., 128., 132.]],
#
#        [[127., 123., 124.],
#         [121., 117., 118.],
#         [ 87.,  83.,  84.],
#         ...,
#         [119., 114., 118.],
#         [127., 122., 126.],
#         [135., 130., 134.]]], dtype=float32)

# %%
x=np.expand_dims(x,axis=0)
x
# Out:
# array([[[[148., 149., 153.],
#          [148., 149., 153.],
#          [148., 149., 153.],
#          ...,
#          [153., 150., 157.],
#          [153., 150., 157.],
#          [153., 150., 157.]],
#
#         [[146., 147., 151.],
#          [146., 147., 151.],
#          [146., 147., 151.],
#          ...,
#          [152., 149., 156.],
#          [152., 149., 156.],
#          [153., 150., 157.]],
#
#         [[145., 146., 150.],
#          [145., 146., 150.],
#          [145., 146., 150.],
#          ...,
#          [150., 147., 154.],
#          [152., 149., 156.],
#          [154., 151., 158.]],
#
#         ...,
#
#         [[122., 118., 119.],
#          [131., 127., 128.],
#          [103.,  99., 100.],
#          ...,
#          [141., 136., 140.],
#          [120., 115., 119.],
#          [139., 134., 138.]],
#
#         [[134., 130., 131.],
#          [ 82.,  78.,  79.],
#          [108., 104., 105.],
#          ...,
#          [129., 124., 128.],
#          [130., 125., 129.],
#          [133., 128., 132.]],
#
#         [[127., 123., 124.],
#          [121., 117., 118.],
#          [ 87.,  83.,  84.],
#          ...,
#          [119., 114., 118.],
#          [127., 122., 126.],
#          [135., 130., 134.]]]], dtype=float32)

# %%
x
# Out:
# array([[[[148., 149., 153.],
#          [148., 149., 153.],
#          [148., 149., 153.],
#          ...,
#          [153., 150., 157.],
#          [153., 150., 157.],
#          [153., 150., 157.]],
#
#         [[146., 147., 151.],
#          [146., 147., 151.],
#          [146., 147., 151.],
#          ...,
#          [152., 149., 156.],
#          [152., 149., 156.],
#          [153., 150., 157.]],
#
#         [[145., 146., 150.],
#          [145., 146., 150.],
#          [145., 146., 150.],
#          ...,
#          [150., 147., 154.],
#          [152., 149., 156.],
#          [154., 151., 158.]],
#
#         ...,
#
#         [[122., 118., 119.],
#          [131., 127., 128.],
#          [103.,  99., 100.],
#          ...,
#          [141., 136., 140.],
#          [120., 115., 119.],
#          [139., 134., 138.]],
#
#         [[134., 130., 131.],
#          [ 82.,  78.,  79.],
#          [108., 104., 105.],
#          ...,
#          [129., 124., 128.],
#          [130., 125., 129.],
#          [133., 128., 132.]],
#
#         [[127., 123., 124.],
#          [121., 117., 118.],
#          [ 87.,  83.,  84.],
#          ...,
#          [119., 114., 118.],
#          [127., 122., 126.],
#          [135., 130., 134.]]]], dtype=float32)
