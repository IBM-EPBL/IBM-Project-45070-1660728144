# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1)

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\train_set",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
# Out:
# Found 11386 images belonging to 9 classes.
# Found 3416 images belonging to 9 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1)

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\train_set",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
# Out:
# Found 11386 images belonging to 9 classes.
# Found 3416 images belonging to 9 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1)

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\train_set",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
# Out:
# Found 11386 images belonging to 9 classes.
# Found 3416 images belonging to 9 classes.

# %%
model=Sequential()
model.add(Convolution2D(32,(3,3),input_shape=(128,128,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=300,kernel_initializer='uniform',activation='relu'))

# %%
model.add(Dense(units=150,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=75,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=9,kernel_initializer='uniform',activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=["accuracy"])
model.fit(x_train,steps_per_epoch=89,epochs=20,validation_data=x_test,validation_steps=27)
# Out:
# Epoch 1/20
# 89/89 [==============================] - 72s 788ms/step - loss: 1.9629 - accuracy: 0.2560 - val_loss: 205.1989 - val_accuracy: 0.3727
# Epoch 2/20
# 89/89 [==============================] - 70s 789ms/step - loss: 1.4169 - accuracy: 0.5014 - val_loss: 273.6411 - val_accuracy: 0.3727
# Epoch 3/20
# 89/89 [==============================] - 69s 776ms/step - loss: 1.1186 - accuracy: 0.6057 - val_loss: 393.7519 - val_accuracy: 0.3854
# Epoch 4/20
# 89/89 [==============================] - 69s 772ms/step - loss: 0.8775 - accuracy: 0.6921 - val_loss: 446.3439 - val_accuracy: 0.3472
# Epoch 5/20
# 89/89 [==============================] - 69s 771ms/step - loss: 0.7720 - accuracy: 0.7335 - val_loss: 750.8200 - val_accuracy: 0.3183
# Epoch 6/20
# 89/89 [==============================] - 69s 769ms/step - loss: 0.6852 - accuracy: 0.7518 - val_loss: 1401.3102 - val_accuracy: 0.2315
# Epoch 7/20
# 89/89 [==============================] - 68s 767ms/step - loss: 0.6419 - accuracy: 0.7730 - val_loss: 1028.9202 - val_accuracy: 0.2650
# Epoch 8/20
# 89/89 [==============================] - 70s 780ms/step - loss: 0.6209 - accuracy: 0.7741 - val_loss: 942.1723 - val_accuracy: 0.3738
# Epoch 9/20
# 89/89 [==============================] - 70s 781ms/step - loss: 0.5679 - accuracy: 0.7907 - val_loss: 1355.3146 - val_accuracy: 0.2870
# Epoch 10/20
# 89/89 [==============================] - 69s 773ms/step - loss: 0.4980 - accuracy: 0.8209 - val_loss: 1537.4943 - val_accuracy: 0.2153
# Epoch 11/20
# 89/89 [==============================] - 70s 779ms/step - loss: 0.5424 - accuracy: 0.8069 - val_loss: 1438.4639 - val_accuracy: 0.2523
# Epoch 12/20
# 89/89 [==============================] - 69s 772ms/step - loss: 0.4508 - accuracy: 0.8388 - val_loss: 1522.8446 - val_accuracy: 0.2685
# Epoch 13/20
# 89/89 [==============================] - 69s 775ms/step - loss: 0.4316 - accuracy: 0.8511 - val_loss: 1959.6537 - val_accuracy: 0.1771
# Epoch 14/20
# 89/89 [==============================] - 69s 772ms/step - loss: 0.4464 - accuracy: 0.8388 - val_loss: 1266.5361 - val_accuracy: 0.3322
# Epoch 15/20
# 89/89 [==============================] - 72s 805ms/step - loss: 0.3720 - accuracy: 0.8758 - val_loss: 1992.7712 - val_accuracy: 0.1678
# Epoch 16/20
# 89/89 [==============================] - 69s 775ms/step - loss: 0.3279 - accuracy: 0.8915 - val_loss: 2267.1602 - val_accuracy: 0.1829
# Epoch 17/20
# 89/89 [==============================] - 69s 772ms/step - loss: 0.3478 - accuracy: 0.8778 - val_loss: 2009.0295 - val_accuracy: 0.2650
# Epoch 18/20
# 89/89 [==============================] - 70s 781ms/step - loss: 0.3886 - accuracy: 0.8683 - val_loss: 2161.1572 - val_accuracy: 0.2650
# Epoch 19/20
# 89/89 [==============================] - 69s 775ms/step - loss: 0.3481 - accuracy: 0.8722 - val_loss: 2363.8223 - val_accuracy: 0.2465
# Epoch 20/20
# 89/89 [==============================] - 69s 779ms/step - loss: 0.3707 - accuracy: 0.8743 - val_loss: 1686.2726 - val_accuracy: 0.3600

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\train",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
# Out:
# Found 5384 images belonging to 6 classes.
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

img=image.load_img(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test\Apple___healthy\0d01a8a3-9faa-4a1f-afe0-be6bffa42056___RS_HL 6204.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
import numpy as nps
x=image.img_to_array(img)
x=nps.expand_dims(x,axis=0)

# %%
pred=(model.predict(x) > 0.5).astype("int32")

# %%
pred

# %%
import requests
from tensorflow.keras.preprocessing import image
model.save(r"C:\Users\DELL\Desktop\fruit-dataset.h5")
model.save('fruit-dataset.h5')
model=load_model('fruit-dataset.h5')

# %%
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
import tensorflow as tf
from flask import Flask, request ,  render_template, redirect, url_for
import os
from werkzeug.utils import secure_filename
from tensorflow.python.keras.backend import set_session

# %%
app= Flask(__name__)
model = load_model("fruit-dataset.h5")
@app.route('/')
def home():
  return render_template('home.html')

# %%
@app.route('/prediction')
def prediction():
  return render_template('predict.html')

# %%
@app.route('/predict',methods=['POST'])
def predict():
  if request.method=='POST':
    f= request.files['images']
    basepath=os.path.dirname(__file__)
    file_path==os.path.join(
        basepath, 'uploads',secure_filename(f.filename))
    f.save(file_path)
    img=image.load_img(file_path, target_size=(128,128))
    x=image.img_to_array(img)
    x=np.expand_dims(x, axis=0)
    plant=request.form['plant']
    print(plant)
    if(plant=="fruit"):
      preds=model.predict_classess(x)
      print(preds)
      df=pd.read_excel('precautions-veg.xlsx')
      print (df.iloc[preds[0]]['cautions'])
    else:
      pred=model1.predict_classes(x)
      df=pd.read_excel('precautions-fruits.xlsx')
      print(df.iloc[preds[0]]['caution'])
      return df.iloc[preds[0]]['caution']

# %%
if __name__=="__main__":
  app.run(debug=False)
