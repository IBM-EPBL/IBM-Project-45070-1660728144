# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
live = imread(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set\Potato___healthy\e693354a-053c-4093-8642-cc8f5f9eb2cc___RS_HL 1746.JPG")
mask = imread(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set\Potato___healthy\bb328d40-e4e6-4b84-a92a-e7cb3922c19d___RS_HL 1829.JPG")

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(live, cmap='gray')
plt.subplot(122), plt.imshow(mask, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(live, cmap='gray')
plt.subplot(122), plt.imshow(live - 20, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(131), plt.imshow(mask - live, cmap='gray')
plt.subplot(132), plt.imshow(-(mask - live + 128), cmap='gray')
plt.subplot(133), plt.imshow(mask - live + 128, cmap='gray')
plt.show()

# %%
shaded = imread(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set\Potato___healthy\e693354a-053c-4093-8642-cc8f5f9eb2cc___RS_HL 1746.JPG")
shading = imread(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set\Potato___healthy\bb328d40-e4e6-4b84-a92a-e7cb3922c19d___RS_HL 1829.JPG")

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(shaded, cmap='gray')
plt.subplot(122), plt.imshow(shading, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
plt.subplot(122), plt.imshow(shaded, cmap='gray')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11500\1289966496.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
xray = imread(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set\Potato___healthy\bb328d40-e4e6-4b84-a92a-e7cb3922c19d___RS_HL 1829.JPG")
mask_xray = imread(r"C:\Users\DELL\Desktop\Veg-dataset\Veg-dataset\test_set\Potato___Early_blight\c5464947-d6f8-4d5e-9cad-009db19adf67___RS_Early.B 7181.JPG")

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(xray, cmap='gray')
plt.subplot(122), plt.imshow(mask_xray, cmap='gray')
plt.show()

# %%
plt.figure()
plt.imshow(np.multiply(xray, mask_xray/255), cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
scan = imread(r'C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test\Corn_(maize)___healthy\2f20e2f8-b6ba-474b-87eb-84ba8adc3bec___R.S_HL 8131 copy 2.jpg')
print(scan.shape)
# Out:
# (256, 256, 3)

# %%
plt.figure(figsize=(7, 7))
plt.imshow(scan, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(211), plt.imshow(xray, cmap='gray')
plt.subplot(212), plt.plot(np.histogram(xray, bins=256)[0])
plt.show()
