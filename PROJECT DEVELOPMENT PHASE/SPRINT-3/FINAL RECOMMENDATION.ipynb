# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fertilizer_data_path = r"C:\Users\DELL\Desktop\archive (2)\fertilizer.csv"
merge_fert = pd.read_csv(fertilizer_data_path)

# %%
merge_fert.head()
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
merge_fert.describe()
# Out:
#        Temparature   Humidity     Moisture    Nitrogen   Potassium  \
# count   205.000000  205.000000  205.000000  205.000000  205.000000
# mean     30.204878   58.990244   43.590244   18.814634    3.219512
# std       3.592882    5.973791   11.236665   11.273115    5.571778
# min      25.000000   50.000000   25.000000    4.000000    0.000000
# 25%      27.000000   54.000000   34.000000   10.000000    0.000000
# 50%      30.000000   60.000000   42.000000   14.000000    0.000000
# 75%      33.000000   64.000000   51.000000   24.000000    7.000000
# max      38.000000   72.000000   65.000000   42.000000   19.000000
#
#        Phosphorous
# count   205.000000
# mean     18.634146
# std      13.494654
# min       0.000000
# 25%       9.000000
# 50%      18.000000
# 75%      30.000000
# max      42.000000

# %%
merge_fert['Crop Type'].unique()
# Out:
# array(['Maize', 'Sugarcane', 'Cotton', 'Tobacco', 'Paddy', 'Barley',
#        'Wheat', 'Millets', 'Oil seeds', 'Pulses', 'Ground Nuts'],
#       dtype=object)

# %%
plt.plot(merge_fert["Temparature"])

# %%
del merge_fert['Temparature']

# %%
plt.plot(merge_fert["Moisture"])

# %%
plt.plot(merge_fert["Nitrogen"])

# %%
sns.heatmap(merge_fert.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
merge_crop = pd.read_csv(r'C:\Users\DELL\Desktop\archive (2)\crop.csv')
reco_fert = merge_fert

# %%
merge_crop['P'] = temp['Humidity']
merge_crop['K'] = temp['Moisture']

# %%
merge_crop
# Out:
#         N    P    K  temperature   humidity        ph    rainfall   label
# 0      90  NaN  NaN    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  NaN  NaN    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  NaN  NaN    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  NaN  NaN    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  NaN  NaN    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ...  ...          ...        ...       ...         ...     ...
# 2195  107  NaN  NaN    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  NaN  NaN    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  NaN  NaN    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  NaN  NaN    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  NaN  NaN    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
del merge_crop['N']

# %%
merge_crop
# Out:
#         P    K  temperature   humidity        ph    rainfall   label
# 0     NaN  NaN    20.879744  82.002744  6.502985  202.935536    rice
# 1     NaN  NaN    21.770462  80.319644  7.038096  226.655537    rice
# 2     NaN  NaN    23.004459  82.320763  7.840207  263.964248    rice
# 3     NaN  NaN    26.491096  80.158363  6.980401  242.864034    rice
# 4     NaN  NaN    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ...          ...        ...       ...         ...     ...
# 2195  NaN  NaN    26.774637  66.413269  6.780064  177.774507  coffee
# 2196  NaN  NaN    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  NaN  NaN    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  NaN  NaN    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  NaN  NaN    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 7 columns]

# %%
merge_crop = merge_crop[['P', 'K','temperature', 'humidity', 'ph', 'rainfall', 'label']]

# %%
merge_crop.to_csv(r"C:\Users\DELL\Desktop\archive\Crop_recommendation.csv",index=False)

# %%
# Checking if everything went fine
df = pd.read_csv(r"C:\Users\DELL\Desktop\archive\Crop_recommendation.csv")

# %%
df.head()
# Out:
#     P   K  temperature   humidity        ph    rainfall label
# 0 NaN NaN    20.879744  82.002744  6.502985  202.935536  rice
# 1 NaN NaN    21.770462  80.319644  7.038096  226.655537  rice
# 2 NaN NaN    23.004459  82.320763  7.840207  263.964248  rice
# 3 NaN NaN    26.491096  80.158363  6.980401  242.864034  rice
# 4 NaN NaN    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 7)
