# %%
test_dir=r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test"

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator (rescale = 1./255, shear_range= 0.2,zoom_range= 0.2, horizontal_flip = True)
test_datagen =ImageDataGenerator (rescale = 1)

# %%
x_train = train_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\train",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test",target_size = (128,128), batch_size = 32,class_mode = 'categorical')
# Out:
# Found 5384 images belonging to 6 classes.
# Found 1686 images belonging to 6 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from tensorflow.keras.models import load_model
model=Sequential()

# %%
model=load_model('fruit-dataset.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test\Corn_(maize)___Northern_Leaf_Blight\0d0f6d14-be5c-4cb8-adb4-2cfd4d5f8540___RS_NLB 3642.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img=image.load_img(r"C:\Users\DELL\Desktop\fruit-dataset\fruit-dataset\test\Corn_(maize)___Northern_Leaf_Blight\0d0f6d14-be5c-4cb8-adb4-2cfd4d5f8540___RS_NLB 3642.JPG"
,target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 298ms/step
# 'Apple___healthy'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 6s 102ms/step - loss: 1172.0488 - accuracy: 0.5440
# [1172.048828125, 0.5440000295639038]
